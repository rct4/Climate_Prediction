# %%
import cdsapi
import climetlab as cml
import numpy as np
import matplotlib.pyplot as plt
import geopandas
import geopy
import xarray as xr
import pandas as pd

import csv
import os
import pickle

import scipy
import sklearn 
from sklearn.cluster import KMeans

import seaborn as sns

# %%
with open("entry_table.dat", "rb") as f:
    final_table = pickle.load(f)

# %%
states = ["Alaska", "Alabama", "Arkansas", "Arizona", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Vermont", "Washington", "Wisconsin", "West Virginia", "Wyoming"]

# %%
# state_dict = {}
# for i in range(len(states)):
#     state_dict[states[i]] = i

# %%
all_states = []
for i in states:
    state_info = []
    for j in final_table:
        if i in str(j['Location'].address):
            state_info.append(j)
    all_states.append(state_info)

# %%
state_dict = {}
for i in range(len(states)):
    state_dict[states[i]] = all_states[i]

print(state_dict)
# Out:
# {'Alaska': [], 'Alabama': [{'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '03', 'Month': '01', 'Year': '2022', 'ID': 2}, {'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '16', 'Month': '01', 'Year': '2022', 'ID': 5}, {'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '12', 'Month': '03', 'Year': '2022', 'ID': 21}, {'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '31', 'Month': '03', 'Year': '2022', 'ID': 30}, {'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '30', 'Month': '11', 'Year': '2022', 'ID': 81}, {'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '23', 'Month': '12', 'Year': '2022', 'ID': 88}, {'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '24', 'Month': '12', 'Year': '2022', 'ID': 94}, {'Location':                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States, 'Day': '03', 'Month': '03', 'Year': '2023', 'ID': 121}], 'Arkansas': [{'Location':                      geometry                  address
# 0  POINT (-92.44791 35.20489)  Arkansas, United States, 'Day': '30', 'Month': '03', 'Year': '2022', 'ID': 28}, {'Location':                      geometry                            address
# 0  POINT (-91.16555 36.00782)  Lawrence, Arkansas, United States, 'Day': '10', 'Month': '08', 'Year': '2022', 'ID': 58}, {'Location':                      geometry                                         address
# 0  POINT (-92.19150 32.53373)  Arkansas Road, 71291, Louisiana, United States, 'Day': '02', 'Month': '01', 'Year': '2023', 'ID': 99}, {'Location':                      geometry                  address
# 0  POINT (-92.44791 35.20489)  Arkansas, United States, 'Day': '25', 'Month': '01', 'Year': '2023', 'ID': 108}, {'Location':                      geometry                  address
# 0  POINT (-92.44791 35.20489)  Arkansas, United States, 'Day': '02', 'Month': '02', 'Year': '2023', 'ID': 114}, {'Location':                      geometry                  address
# 0  POINT (-92.44791 35.20489)  Arkansas, United States, 'Day': '31', 'Month': '03', 'Year': '2023', 'ID': 136}], 'Arizona': [], 'California': [{'Location':                       geometry                              address
# 0  POINT (-119.99194 38.05694)  Tuolumne, California, United States, 'Day': '02', 'Month': '01', 'Year': '2022', 'ID': 0}, {'Location':                       geometry                            address
# 0  POINT (-121.99792 40.79651)  Shasta, California, United States, 'Day': '01', 'Month': '09', 'Year': '2022', 'ID': 61}, {'Location':                       geometry                            address
# 0  POINT (-121.99792 40.79651)  Shasta, California, United States, 'Day': '06', 'Month': '09', 'Year': '2022', 'ID': 63}, {'Location':                       geometry                            address
# 0  POINT (-121.99792 40.79651)  Shasta, California, United States, 'Day': '07', 'Month': '09', 'Year': '2022', 'ID': 64}, {'Location':                       geometry                            address
# 0  POINT (-121.99792 40.79651)  Shasta, California, United States, 'Day': '08', 'Month': '09', 'Year': '2022', 'ID': 65}, {'Location':                       geometry                            address
# 0  POINT (-121.99792 40.79651)  Shasta, California, United States, 'Day': '09', 'Month': '09', 'Year': '2022', 'ID': 66}, {'Location':                       geometry                                address
# 0  POINT (-121.49389 38.58106)  Sacramento, California, United States, 'Day': '31', 'Month': '12', 'Year': '2022', 'ID': 98}, {'Location':                       geometry                                address
# 0  POINT (-121.49389 38.58106)  Sacramento, California, United States, 'Day': '07', 'Month': '01', 'Year': '2023', 'ID': 100}, {'Location':                       geometry                                 address
# 0  POINT (-118.24277 34.05369)  Los Angeles, California, United States, 'Day': '25', 'Month': '02', 'Year': '2023', 'ID': 118}], 'Colorado': [], 'Connecticut': [{'Location':                      geometry                     address
# 0  POINT (-72.73422 41.65002)  Connecticut, United States, 'Day': '29', 'Month': '01', 'Year': '2022', 'ID': 6}, {'Location':                      geometry                     address
# 0  POINT (-72.73422 41.65002)  Connecticut, United States, 'Day': '18', 'Month': '02', 'Year': '2022', 'ID': 15}, {'Location':                      geometry                     address
# 0  POINT (-72.73422 41.65002)  Connecticut, United States, 'Day': '14', 'Month': '10', 'Year': '2022', 'ID': 71}, {'Location':                      geometry                     address
# 0  POINT (-72.73422 41.65002)  Connecticut, United States, 'Day': '23', 'Month': '01', 'Year': '2023', 'ID': 101}, {'Location':                      geometry                     address
# 0  POINT (-72.73422 41.65002)  Connecticut, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 126}, {'Location':                      geometry                     address
# 0  POINT (-72.73422 41.65002)  Connecticut, United States, 'Day': '01', 'Month': '05', 'Year': '2023', 'ID': 142}], 'Delaware': [], 'Florida': [{'Location':                      geometry                 address
# 0  POINT (-81.46398 27.75677)  Florida, United States, 'Day': '12', 'Month': '03', 'Year': '2022', 'ID': 24}, {'Location':                      geometry                 address
# 0  POINT (-81.46398 27.75677)  Florida, United States, 'Day': '31', 'Month': '03', 'Year': '2022', 'ID': 32}, {'Location':                      geometry                               address
# 0  POINT (-82.34881 27.91845)  Hillsborough, Florida, United States, 'Day': '28', 'Month': '09', 'Year': '2022', 'ID': 68}, {'Location':                      geometry                       address
# 0  POINT (-81.72688 27.94485)  Polk, Florida, United States, 'Day': '29', 'Month': '09', 'Year': '2022', 'ID': 69}, {'Location':                      geometry                          address
# 0  POINT (-82.36401 29.67557)  Alachua, Florida, United States, 'Day': '10', 'Month': '11', 'Year': '2022', 'ID': 80}, {'Location':                      geometry                         address
# 0  POINT (-81.72305 29.62662)  Putnam, Florida, United States, 'Day': '22', 'Month': '05', 'Year': '2023', 'ID': 148}], 'Georgia': [{'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '03', 'Month': '01', 'Year': '2022', 'ID': 1}, {'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '16', 'Month': '01', 'Year': '2022', 'ID': 4}, {'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '12', 'Month': '03', 'Year': '2022', 'ID': 22}, {'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '31', 'Month': '03', 'Year': '2022', 'ID': 29}, {'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '30', 'Month': '11', 'Year': '2022', 'ID': 83}, {'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '23', 'Month': '12', 'Year': '2022', 'ID': 89}, {'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '24', 'Month': '12', 'Year': '2022', 'ID': 95}, {'Location':                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States, 'Day': '03', 'Month': '03', 'Year': '2023', 'ID': 122}], 'Hawaii': [], 'Iowa': [{'Location':                      geometry  \
# 0  POINT (-94.18770 42.49331)
#
#                                              address
# 0  Fort Dodge Iowa Illinois Gas & Electric Millda...  , 'Day': '23', 'Month': '04', 'Year': '2022', 'ID': 38}], 'Idaho': [], 'Illinois': [{'Location':                      geometry  \
# 0  POINT (-94.18770 42.49331)
#
#                                              address
# 0  Fort Dodge Iowa Illinois Gas & Electric Millda...  , 'Day': '23', 'Month': '04', 'Year': '2022', 'ID': 38}, {'Location':                      geometry                  address
# 0  POINT (-89.43373 40.07966)  Illinois, United States, 'Day': '17', 'Month': '06', 'Year': '2022', 'ID': 50}, {'Location':                      geometry                  address
# 0  POINT (-89.43373 40.07966)  Illinois, United States, 'Day': '31', 'Month': '03', 'Year': '2023', 'ID': 137}], 'Indiana': [{'Location':                      geometry                 address
# 0  POINT (-86.17469 40.32701)  Indiana, United States, 'Day': '12', 'Month': '06', 'Year': '2022', 'ID': 47}], 'Kansas': [{'Location':                      geometry                address
# 0  POINT (-98.58219 38.27312)  Kansas, United States, 'Day': '08', 'Month': '06', 'Year': '2022', 'ID': 40}], 'Kentucky': [{'Location':                      geometry                  address
# 0  POINT (-85.15514 37.57260)  Kentucky, United States, 'Day': '13', 'Month': '06', 'Year': '2022', 'ID': 49}, {'Location':                      geometry                                       address
# 0  POINT (-84.15966 36.74342)  Williamsburg, 40769, Kentucky, United States, 'Day': '03', 'Month': '03', 'Year': '2023', 'ID': 124}], 'Louisiana': [{'Location':                      geometry                   address
# 0  POINT (-92.00713 30.87039)  Louisiana, United States, 'Day': '30', 'Month': '03', 'Year': '2022', 'ID': 26}, {'Location':                      geometry                                         address
# 0  POINT (-92.19150 32.53373)  Arkansas Road, 71291, Louisiana, United States, 'Day': '02', 'Month': '01', 'Year': '2023', 'ID': 99}, {'Location':                      geometry                   address
# 0  POINT (-92.00713 30.87039)  Louisiana, United States, 'Day': '25', 'Month': '01', 'Year': '2023', 'ID': 110}], 'Massachusetts': [{'Location':                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States, 'Day': '29', 'Month': '01', 'Year': '2022', 'ID': 7}, {'Location':                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States, 'Day': '18', 'Month': '02', 'Year': '2022', 'ID': 17}, {'Location':                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States, 'Day': '14', 'Month': '10', 'Year': '2022', 'ID': 72}, {'Location':                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States, 'Day': '16', 'Month': '12', 'Year': '2022', 'ID': 84}, {'Location':                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States, 'Day': '23', 'Month': '01', 'Year': '2023', 'ID': 103}, {'Location':                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 127}, {'Location':                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States, 'Day': '01', 'Month': '05', 'Year': '2023', 'ID': 143}], 'Maryland': [{'Location':                      geometry                                address
# 0  POINT (-76.57345 38.97226)  Anne Arundel, Maryland, United States, 'Day': '04', 'Month': '08', 'Year': '2022', 'ID': 57}], 'Maine': [{'Location':                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States, 'Day': '29', 'Month': '01', 'Year': '2022', 'ID': 11}, {'Location':                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States, 'Day': '18', 'Month': '02', 'Year': '2022', 'ID': 16}, {'Location':                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States, 'Day': '14', 'Month': '10', 'Year': '2022', 'ID': 73}, {'Location':                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States, 'Day': '16', 'Month': '12', 'Year': '2022', 'ID': 87}, {'Location':                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States, 'Day': '23', 'Month': '01', 'Year': '2023', 'ID': 106}, {'Location':                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 131}, {'Location':                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States, 'Day': '01', 'Month': '05', 'Year': '2023', 'ID': 145}], 'Michigan': [{'Location':                      geometry                            address
# 0  POINT (-86.12935 43.24846)  Muskegon, Michigan, United States, 'Day': '23', 'Month': '07', 'Year': '2022', 'ID': 53}, {'Location':                      geometry                           address
# 0  POINT (-85.88615 42.58672)  Allegan, Michigan, United States, 'Day': '03', 'Month': '08', 'Year': '2022', 'ID': 56}, {'Location':                      geometry                             address
# 0  POINT (-85.53728 42.24950)  Kalamazoo, Michigan, United States, 'Day': '05', 'Month': '11', 'Year': '2022', 'ID': 78}, {'Location':                      geometry  \
# 0  POINT (-87.38122 44.83195)
#
#                                              address
# 0  Michigan Street Bridge, Michigan Street, 54235...  , 'Day': '23', 'Month': '02', 'Year': '2023', 'ID': 117}, {'Location':                      geometry                           address
# 0  POINT (-85.79450 43.51212)  Newaygo, Michigan, United States, 'Day': '27', 'Month': '02', 'Year': '2023', 'ID': 119}], 'Minnesota': [{'Location':                      geometry                   address
# 0  POINT (-94.61133 45.98966)  Minnesota, United States, 'Day': '03', 'Month': '08', 'Year': '2022', 'ID': 54}], 'Missouri': [{'Location':                      geometry                  address
# 0  POINT (-92.56179 38.76048)  Missouri, United States, 'Day': '08', 'Month': '06', 'Year': '2022', 'ID': 41}, {'Location':                      geometry                  address
# 0  POINT (-92.56179 38.76048)  Missouri, United States, 'Day': '08', 'Month': '06', 'Year': '2022', 'ID': 43}, {'Location':                      geometry                  address
# 0  POINT (-92.56179 38.76048)  Missouri, United States, 'Day': '17', 'Month': '06', 'Year': '2022', 'ID': 51}, {'Location':                      geometry                          address
# 0  POINT (-94.31034 37.17652)  Jasper, Missouri, United States, 'Day': '23', 'Month': '12', 'Year': '2022', 'ID': 91}], 'Mississippi': [{'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '03', 'Month': '01', 'Year': '2022', 'ID': 3}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '12', 'Month': '03', 'Year': '2022', 'ID': 23}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '30', 'Month': '03', 'Year': '2022', 'ID': 27}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '31', 'Month': '03', 'Year': '2022', 'ID': 31}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '30', 'Month': '11', 'Year': '2022', 'ID': 82}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '23', 'Month': '12', 'Year': '2022', 'ID': 90}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '24', 'Month': '12', 'Year': '2022', 'ID': 96}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '25', 'Month': '01', 'Year': '2023', 'ID': 111}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '02', 'Month': '02', 'Year': '2023', 'ID': 115}, {'Location':                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States, 'Day': '03', 'Month': '03', 'Year': '2023', 'ID': 123}], 'Montana': [], 'North Carolina': [{'Location':                      geometry                        address
# 0  POINT (-79.03929 35.67296)  North Carolina, United States, 'Day': '30', 'Month': '09', 'Year': '2022', 'ID': 70}, {'Location':                      geometry                        address
# 0  POINT (-79.03929 35.67296)  North Carolina, United States, 'Day': '24', 'Month': '12', 'Year': '2022', 'ID': 92}], 'North Dakota': [{'Location':                       geometry                      address
# 0  POINT (-100.54074 47.62015)  North Dakota, United States, 'Day': '22', 'Month': '04', 'Year': '2022', 'ID': 35}, {'Location':                      geometry  \
# 0  POINT (-96.81827 46.89715)
#
#                                              address
# 0  North Dakota State University, 13th Avenue Nor...  , 'Day': '22', 'Month': '04', 'Year': '2022', 'ID': 36}, {'Location':                       geometry                                 address
# 0  POINT (-102.36033 48.23032)  Mountrail, North Dakota, United States, 'Day': '23', 'Month': '04', 'Year': '2022', 'ID': 37}], 'Nebraska': [{'Location':                      geometry                  address
# 0  POINT (-99.58738 41.73702)  Nebraska, United States, 'Day': '08', 'Month': '06', 'Year': '2022', 'ID': 42}], 'New Hampshire': [{'Location':                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States, 'Day': '29', 'Month': '01', 'Year': '2022', 'ID': 8}, {'Location':                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States, 'Day': '18', 'Month': '02', 'Year': '2022', 'ID': 18}, {'Location':                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States, 'Day': '14', 'Month': '10', 'Year': '2022', 'ID': 75}, {'Location':                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States, 'Day': '16', 'Month': '12', 'Year': '2022', 'ID': 86}, {'Location':                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States, 'Day': '23', 'Month': '01', 'Year': '2023', 'ID': 105}, {'Location':                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 130}, {'Location':                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States, 'Day': '01', 'Month': '05', 'Year': '2023', 'ID': 146}], 'New Jersey': [], 'New Mexico': [], 'Nevada': [], 'New York': [{'Location':                      geometry                          address
# 0  POINT (-74.26185 41.86893)  Ulster, New York, United States, 'Day': '04', 'Month': '02', 'Year': '2022', 'ID': 14}, {'Location':                      geometry                          address
# 0  POINT (-75.84041 42.14556)  Broome, New York, United States, 'Day': '19', 'Month': '04', 'Year': '2022', 'ID': 34}, {'Location':                      geometry                            address
# 0  POINT (-74.00602 40.71273)  New York, New York, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 132}], 'Ohio': [{'Location':                      geometry              address
# 0  POINT (-82.68814 40.22536)  Ohio, United States, 'Day': '03', 'Month': '02', 'Year': '2022', 'ID': 13}, {'Location':                      geometry              address
# 0  POINT (-82.68814 40.22536)  Ohio, United States, 'Day': '12', 'Month': '06', 'Year': '2022', 'ID': 44}, {'Location':                      geometry              address
# 0  POINT (-82.68814 40.22536)  Ohio, United States, 'Day': '13', 'Month': '06', 'Year': '2022', 'ID': 48}, {'Location':                      geometry              address
# 0  POINT (-82.68814 40.22536)  Ohio, United States, 'Day': '25', 'Month': '03', 'Year': '2023', 'ID': 133}, {'Location':                      geometry              address
# 0  POINT (-82.68814 40.22536)  Ohio, United States, 'Day': '01', 'Month': '04', 'Year': '2023', 'ID': 138}], 'Oklahoma': [], 'Oregon': [{'Location':                       geometry                           address
# 0  POINT (-122.40064 45.50938)  Multnomah, Oregon, United States, 'Day': '11', 'Month': '04', 'Year': '2022', 'ID': 33}], 'Pennsylvania': [], 'Rhode Island': [{'Location':                      geometry                      address
# 0  POINT (-71.59924 41.79624)  Rhode Island, United States, 'Day': '29', 'Month': '01', 'Year': '2022', 'ID': 9}, {'Location':                      geometry                      address
# 0  POINT (-71.59924 41.79624)  Rhode Island, United States, 'Day': '18', 'Month': '02', 'Year': '2022', 'ID': 20}, {'Location':                      geometry                      address
# 0  POINT (-71.59924 41.79624)  Rhode Island, United States, 'Day': '14', 'Month': '10', 'Year': '2022', 'ID': 74}, {'Location':                      geometry                      address
# 0  POINT (-71.59924 41.79624)  Rhode Island, United States, 'Day': '23', 'Month': '01', 'Year': '2023', 'ID': 102}, {'Location':                      geometry                      address
# 0  POINT (-71.59924 41.79624)  Rhode Island, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 129}, {'Location':                      geometry                      address
# 0  POINT (-71.59924 41.79624)  Rhode Island, United States, 'Day': '01', 'Month': '05', 'Year': '2023', 'ID': 144}], 'South Carolina': [{'Location':                      geometry                        address
# 0  POINT (-80.43637 33.68744)  South Carolina, United States, 'Day': '24', 'Month': '12', 'Year': '2022', 'ID': 93}], 'South Dakota': [], 'Tennessee': [{'Location':                      geometry                           address
# 0  POINT (-89.87398 35.17826)  Shelby, Tennessee, United States, 'Day': '03', 'Month': '02', 'Year': '2022', 'ID': 12}], 'Texas': [{'Location':                      geometry                         address
# 0  POINT (-95.62582 31.78192)  Anderson, Texas, United States, 'Day': '21', 'Month': '03', 'Year': '2022', 'ID': 25}, {'Location':                      geometry                       address
# 0  POINT (-95.37412 29.81198)  Harris, Texas, United States, 'Day': '22', 'Month': '05', 'Year': '2022', 'ID': 39}, {'Location':                      geometry                       address
# 0  POINT (-95.37412 29.81198)  Harris, Texas, United States, 'Day': '10', 'Month': '08', 'Year': '2022', 'ID': 59}, {'Location':                       geometry                        address
# 0  POINT (-106.22304 31.80722)  El Paso, Texas, United States, 'Day': '22', 'Month': '08', 'Year': '2022', 'ID': 60}, {'Location':                      geometry                               address
# 0  POINT (-97.33570 32.75137)  Tarrant County, Texas, United States, 'Day': '04', 'Month': '09', 'Year': '2022', 'ID': 62}, {'Location':                       geometry                        address
# 0  POINT (-106.22304 31.80722)  El Paso, Texas, United States, 'Day': '13', 'Month': '09', 'Year': '2022', 'ID': 67}, {'Location':                      geometry                       address
# 0  POINT (-95.37412 29.81198)  Harris, Texas, United States, 'Day': '24', 'Month': '01', 'Year': '2023', 'ID': 107}, {'Location':                      geometry               address
# 0  POINT (-98.54561 31.26389)  Texas, United States, 'Day': '25', 'Month': '01', 'Year': '2023', 'ID': 109}, {'Location':                      geometry                       address
# 0  POINT (-96.79686 32.77627)  Dallas, Texas, United States, 'Day': '31', 'Month': '01', 'Year': '2023', 'ID': 112}, {'Location':                      geometry                       address
# 0  POINT (-97.75614 30.28786)  Travis, Texas, United States, 'Day': '01', 'Month': '02', 'Year': '2023', 'ID': 113}, {'Location':                      geometry               address
# 0  POINT (-98.54561 31.26389)  Texas, United States, 'Day': '02', 'Month': '02', 'Year': '2023', 'ID': 116}, {'Location':                      geometry                         address
# 0  POINT (-97.72158 33.62058)  Montague, Texas, United States, 'Day': '02', 'Month': '03', 'Year': '2023', 'ID': 120}, {'Location':                      geometry                        address
# 0  POINT (-98.21644 26.35303)  Hidalgo, Texas, United States, 'Day': '29', 'Month': '04', 'Year': '2023', 'ID': 141}], 'Utah': [], 'Virginia': [{'Location':                      geometry                       address
# 0  POINT (-80.84084 38.47584)  West Virginia, United States, 'Day': '12', 'Month': '06', 'Year': '2022', 'ID': 45}, {'Location':                      geometry                  address
# 0  POINT (-78.49277 37.12322)  Virginia, United States, 'Day': '12', 'Month': '06', 'Year': '2022', 'ID': 46}, {'Location':                      geometry                  address
# 0  POINT (-78.49277 37.12322)  Virginia, United States, 'Day': '22', 'Month': '06', 'Year': '2022', 'ID': 52}, {'Location':                      geometry                       address
# 0  POINT (-80.84084 38.47584)  West Virginia, United States, 'Day': '25', 'Month': '03', 'Year': '2023', 'ID': 134}, {'Location':                      geometry                  address
# 0  POINT (-78.49277 37.12322)  Virginia, United States, 'Day': '25', 'Month': '03', 'Year': '2023', 'ID': 135}, {'Location':                      geometry                       address
# 0  POINT (-80.84084 38.47584)  West Virginia, United States, 'Day': '01', 'Month': '04', 'Year': '2023', 'ID': 139}, {'Location':                      geometry                  address
# 0  POINT (-78.49277 37.12322)  Virginia, United States, 'Day': '01', 'Month': '04', 'Year': '2023', 'ID': 140}], 'Vermont': [{'Location':                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States, 'Day': '29', 'Month': '01', 'Year': '2022', 'ID': 10}, {'Location':                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States, 'Day': '18', 'Month': '02', 'Year': '2022', 'ID': 19}, {'Location':                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States, 'Day': '14', 'Month': '10', 'Year': '2022', 'ID': 76}, {'Location':                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States, 'Day': '16', 'Month': '12', 'Year': '2022', 'ID': 85}, {'Location':                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States, 'Day': '23', 'Month': '01', 'Year': '2023', 'ID': 104}, {'Location':                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 128}, {'Location':                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States, 'Day': '01', 'Month': '05', 'Year': '2023', 'ID': 147}], 'Washington': [{'Location':                       geometry                            address
# 0  POINT (-122.68424 48.21627)  Island, Washington, United States, 'Day': '04', 'Month': '11', 'Year': '2022', 'ID': 77}, {'Location':                       geometry                          address
# 0  POINT (-121.86221 47.48734)  King, Washington, United States, 'Day': '26', 'Month': '12', 'Year': '2022', 'ID': 97}], 'Wisconsin': [{'Location':                      geometry                   address
# 0  POINT (-89.68846 44.43090)  Wisconsin, United States, 'Day': '03', 'Month': '08', 'Year': '2022', 'ID': 55}, {'Location':                      geometry                   address
# 0  POINT (-89.68846 44.43090)  Wisconsin, United States, 'Day': '05', 'Month': '11', 'Year': '2022', 'ID': 79}, {'Location':                      geometry                                    address
# 0  POINT (-88.54130 42.66752)  Walworth County, Wisconsin, United States, 'Day': '09', 'Month': '03', 'Year': '2023', 'ID': 125}], 'West Virginia': [{'Location':                      geometry                       address
# 0  POINT (-80.84084 38.47584)  West Virginia, United States, 'Day': '12', 'Month': '06', 'Year': '2022', 'ID': 45}, {'Location':                      geometry                       address
# 0  POINT (-80.84084 38.47584)  West Virginia, United States, 'Day': '25', 'Month': '03', 'Year': '2023', 'ID': 134}, {'Location':                      geometry                       address
# 0  POINT (-80.84084 38.47584)  West Virginia, United States, 'Day': '01', 'Month': '04', 'Year': '2023', 'ID': 139}], 'Wyoming': []}

# %%
for i in final_table:
    if 'York' in str(i['Location'].address):
        print(i)
        file_name = i['Month'] + '-' + i['Day'] + '-' + i['Year'] + '.nc'
        x = xr.open_dataset('../datafiles/' + file_name)
        currLocation = i['Location']
        # print(x)
        # lat = []
        # lon = []
        # for j in range(100):
        #     diff_lat = (j - 1) * 0.25
        #     for k in range(100):
        #         diff_lon = (k - 1) * 0.25
        #         lat.append(currLocation.geometry.y.values[0] + diff_lat)
        #         lon.append(currLocation.geometry.x.values[0]+360 + diff_lon)

        datetime = i['Year'] + '-' + i['Month'] + '-' + i['Day'] + 'T12:00:00'


        lat = currLocation.geometry.y.values[0]
        lon = currLocation.geometry.x.values[0] + 360
        locate =  x.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5))
        # print(locate)
        # print(locate.sf)
        # print(locate.sf.to_numpy())
        # print(locate.u10.to_numpy())
        # print(locate.v10.to_numpy())
        wind_ave = np.sqrt(np.square(locate.u10.to_numpy())+np.square(locate.v10.to_numpy()))
        
        # print(wind_ave)
# Out:
# {'Location':                      geometry                          address
# 0  POINT (-74.26185 41.86893)  Ulster, New York, United States, 'Day': '04', 'Month': '02', 'Year': '2022', 'ID': 14}
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 273.2 273.5 273.8 274.0 ... 297.5 297.8 298.0
#   * latitude   (latitude) float32 54.25 54.0 53.75 53.5 ... 30.0 29.75 29.5
#     time       datetime64[ns] 2022-02-04T12:00:00
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-01-25 07:45:09 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# {'Location':                      geometry                          address
# 0  POINT (-75.84041 42.14556)  Broome, New York, United States, 'Day': '19', 'Month': '04', 'Year': '2022', 'ID': 34}
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 271.8 272.0 272.2 272.5 ... 296.0 296.2 296.5
#   * latitude   (latitude) float32 54.5 54.25 54.0 53.75 ... 30.25 30.0 29.75
#     time       datetime64[ns] 2022-04-19T12:00:00
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-01-25 10:06:00 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# {'Location':                      geometry                            address
# 0  POINT (-74.00602 40.71273)  New York, New York, United States, 'Day': '14', 'Month': '03', 'Year': '2023', 'ID': 132}
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 273.5 273.8 274.0 274.2 ... 297.8 298.0 298.2
#   * latitude   (latitude) float32 53.0 52.75 52.5 52.25 ... 28.75 28.5 28.25
#     time       datetime64[ns] 2023-03-14T12:00:00
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-01-26 03:29:23 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
snow = locate.sf.to_numpy()
temp = locate.t2m.to_numpy()
print(snow.shape)
print(wind_ave.shape)
# Out:
# (100, 100)
# (100, 100)

# %%
sf1d = snow.ravel()
print(sf1d)
w1d = wind_ave.ravel()
print(w1d)
t1d = temp.ravel()
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# [ 3.3849232  3.4527605  3.580342  ... 10.000216   9.879075   9.762298 ]

# %%
plt.scatter(t1d,w1d)
plt.show()

# %%
max = 0
state_most = ''
for i in range(len(states)):
    if (len(all_states[i]) > max):
        max = len(all_states[i])
        state_most = states[i]
print(state_most)
# Out:
# Texas

# %%
print(state_dict['Texas'])
# Out:
# [{'Location':                      geometry                         address
# 0  POINT (-95.62582 31.78192)  Anderson, Texas, United States, 'Day': '21', 'Month': '03', 'Year': '2022', 'ID': 25}, {'Location':                      geometry                       address
# 0  POINT (-95.37412 29.81198)  Harris, Texas, United States, 'Day': '22', 'Month': '05', 'Year': '2022', 'ID': 39}, {'Location':                      geometry                       address
# 0  POINT (-95.37412 29.81198)  Harris, Texas, United States, 'Day': '10', 'Month': '08', 'Year': '2022', 'ID': 59}, {'Location':                       geometry                        address
# 0  POINT (-106.22304 31.80722)  El Paso, Texas, United States, 'Day': '22', 'Month': '08', 'Year': '2022', 'ID': 60}, {'Location':                      geometry                               address
# 0  POINT (-97.33570 32.75137)  Tarrant County, Texas, United States, 'Day': '04', 'Month': '09', 'Year': '2022', 'ID': 62}, {'Location':                       geometry                        address
# 0  POINT (-106.22304 31.80722)  El Paso, Texas, United States, 'Day': '13', 'Month': '09', 'Year': '2022', 'ID': 67}, {'Location':                      geometry                       address
# 0  POINT (-95.37412 29.81198)  Harris, Texas, United States, 'Day': '24', 'Month': '01', 'Year': '2023', 'ID': 107}, {'Location':                      geometry               address
# 0  POINT (-98.54561 31.26389)  Texas, United States, 'Day': '25', 'Month': '01', 'Year': '2023', 'ID': 109}, {'Location':                      geometry                       address
# 0  POINT (-96.79686 32.77627)  Dallas, Texas, United States, 'Day': '31', 'Month': '01', 'Year': '2023', 'ID': 112}, {'Location':                      geometry                       address
# 0  POINT (-97.75614 30.28786)  Travis, Texas, United States, 'Day': '01', 'Month': '02', 'Year': '2023', 'ID': 113}, {'Location':                      geometry               address
# 0  POINT (-98.54561 31.26389)  Texas, United States, 'Day': '02', 'Month': '02', 'Year': '2023', 'ID': 116}, {'Location':                      geometry                         address
# 0  POINT (-97.72158 33.62058)  Montague, Texas, United States, 'Day': '02', 'Month': '03', 'Year': '2023', 'ID': 120}, {'Location':                      geometry                        address
# 0  POINT (-98.21644 26.35303)  Hidalgo, Texas, United States, 'Day': '29', 'Month': '04', 'Year': '2023', 'ID': 141}]

# %%
means = xr.open_dataset('../../a/state_means/global_mean.nc')
for i in states:
    state_coords = geopandas.tools.geocode(i)
    # datetime = i['Year'] + '-' + i['Month'] + '-' + i['Day'] + 'T12:00:00'

    print(state_coords)
    lat = state_coords.geometry.y.values[0]
    lon = state_coords.geometry.x.values[0] + 360
    locate =  means.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5))
    locate.to_netcdf('../../a/state_means/' + i + '_mean.nc')
# Out:
#                       geometry                address
# 0  POINT (-149.68091 64.44596)  Alaska, United States
#                      geometry                 address
# 0  POINT (-86.82953 33.25888)  Alabama, United States
#                      geometry                  address
# 0  POINT (-92.44791 35.20489)  Arkansas, United States
#                       geometry                 address
# 0  POINT (-111.76327 34.39534)  Arizona, United States
#                       geometry                    address
# 0  POINT (-118.75600 36.70146)  California, United States
#                       geometry                  address
# 0  POINT (-105.60772 38.72518)  Colorado, United States
#                      geometry                     address
# 0  POINT (-72.73422 41.65002)  Connecticut, United States
#                      geometry                  address
# 0  POINT (-75.40133 38.69205)  Delaware, United States
#                      geometry                 address
# 0  POINT (-81.46398 27.75677)  Florida, United States
#                      geometry                 address
# 0  POINT (-83.11374 32.32938)  Georgia, United States
#                       geometry                address
# 0  POINT (-155.42837 19.59380)  Hawaii, United States
#                      geometry              address
# 0  POINT (-93.31227 41.92167)  Iowa, United States
#                       geometry               address
# 0  POINT (-114.01541 43.64476)  Idaho, United States
#                      geometry                  address
# 0  POINT (-89.43373 40.07966)  Illinois, United States
#                      geometry                 address
# 0  POINT (-86.17469 40.32701)  Indiana, United States
#                      geometry                address
# 0  POINT (-98.58219 38.27312)  Kansas, United States
#                      geometry                  address
# 0  POINT (-85.15514 37.57260)  Kentucky, United States
#                      geometry                   address
# 0  POINT (-92.00713 30.87039)  Louisiana, United States
#                      geometry                       address
# 0  POINT (-72.03237 42.37888)  Massachusetts, United States
#                      geometry                  address
# 0  POINT (-76.93821 39.51624)  Maryland, United States
#                      geometry               address
# 0  POINT (-68.85902 45.70910)  Maine, United States
#                      geometry                  address
# 0  POINT (-84.68243 43.62120)  Michigan, United States
#                      geometry                   address
# 0  POINT (-94.61133 45.98966)  Minnesota, United States
#                      geometry                  address
# 0  POINT (-92.56179 38.76048)  Missouri, United States
#                      geometry                     address
# 0  POINT (-89.73485 32.97153)  Mississippi, United States
#                       geometry                 address
# 0  POINT (-109.63876 47.37527)  Montana, United States
#                      geometry                        address
# 0  POINT (-79.03929 35.67296)  North Carolina, United States
#                       geometry                      address
# 0  POINT (-100.54074 47.62015)  North Dakota, United States
#                      geometry                  address
# 0  POINT (-99.58738 41.73702)  Nebraska, United States
#                      geometry                       address
# 0  POINT (-71.65540 43.48491)  New Hampshire, United States
#                      geometry                    address
# 0  POINT (-74.40416 40.07574)  New Jersey, United States
#                       geometry                    address
# 0  POINT (-105.99605 34.58021)  New Mexico, United States
#                       geometry                address
# 0  POINT (-116.85372 39.51588)  Nevada, United States
#                      geometry                            address
# 0  POINT (-74.00602 40.71273)  New York, New York, United States
#                      geometry              address
# 0  POINT (-82.68814 40.22536)  Ohio, United States
#                      geometry                  address
# 0  POINT (-97.26841 34.95508)  Oklahoma, United States
#                       geometry                address
# 0  POINT (-120.73726 43.97928)  Oregon, United States
#                      geometry                      address
# 0  POINT (-77.72788 40.96999)  Pennsylvania, United States
#                      geometry                      address
# 0  POINT (-71.59924 41.79624)  Rhode Island, United States
#                      geometry                        address
# 0  POINT (-80.43637 33.68744)  South Carolina, United States
#                       geometry                      address
# 0  POINT (-100.34876 44.64718)  South Dakota, United States
#                      geometry                   address
# 0  POINT (-86.28201 35.77301)  Tennessee, United States
#                      geometry               address
# 0  POINT (-98.54561 31.26389)  Texas, United States
#                       geometry              address
# 0  POINT (-111.71436 39.42252)  Utah, United States
#                      geometry                  address
# 0  POINT (-78.49277 37.12322)  Virginia, United States
#                      geometry                 address
# 0  POINT (-72.50026 44.59907)  Vermont, United States
#                      geometry                                          address
# 0  POINT (-77.03654 38.89504)  Washington, District of Columbia, United States
#                      geometry                   address
# 0  POINT (-89.68846 44.43090)  Wisconsin, United States
#                      geometry                       address
# 0  POINT (-80.84084 38.47584)  West Virginia, United States
#                       geometry                 address
# 0  POINT (-107.56853 43.17003)  Wyoming, United States

# %%
start = True
state_anoms = []
for state in states:
    anom_total = []
    for i in state_dict[state]:
        means = xr.open_dataset('../../a/state_means/global_mean.nc')

        file_name = i['Month'] + '-' + i['Day'] + '-' + i['Year'] + '.nc'
        x = xr.open_dataset('../datafiles/' + file_name)
        currLocation = i['Location']
        datetime = i['Year'] + '-' + i['Month'] + '-' + i['Day'] + 'T12:00:00'

        # print(i['Year'] + '-' + i['Month'] + '-' + i['Day'])

        
        # print(state_mean.time)

        lat = currLocation.geometry.y.values[0]
        lon = currLocation.geometry.x.values[0] + 360.
        # print(lat,lon)
        # print(means)
        # print(x)
        state_mean = means.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5),time=i['Year'] + '-' + i['Month'] + '-01')
        locate =  x.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5), time=datetime)

        # state_mean.t2m.plot()

        # print(state_mean.t2m.to_numpy())
        # print(locate.t2m.to_numpy())


        anom = locate.t2m.to_numpy() - state_mean.t2m.to_numpy()

        if start:
            start = False
            anom_total = anom.flatten()
        else:
            anom_total = np.hstack((anom_total,anom.flatten()))
    state_anoms.append(anom_total)

# %%
# path = "/data/keeling/a/rct4/work/notebooks/"
# dir_list = os.listdir(path)

# for i in dir_list:
#     if ".png" in i:
#         os.remove(path + i)

# %%
for i in range(len(states)):
    plt.figure()
    plt.title(states[i] + ' t2m')
    plt.hist(state_anoms[i], color='blue', edgecolor ='black', bins=60)
    plt.savefig('../visuals/t2m_' + states[i] + '_hist.png')
# Out:
# /tmp/ipykernel_58441/4163827606.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
start = True
state_sf_anoms = []
for state in states:
    anom_total = []
    for i in state_dict[state]:
        means = xr.open_dataset('../../a/state_means/global_mean.nc')

        file_name = i['Month'] + '-' + i['Day'] + '-' + i['Year'] + '.nc'
        x = xr.open_dataset('../datafiles/' + file_name)
        currLocation = i['Location']
        datetime = i['Year'] + '-' + i['Month'] + '-' + i['Day'] + 'T12:00:00'

        # print(i['Year'] + '-' + i['Month'] + '-' + i['Day'])

        

        # print(state_mean.time)

        lat = currLocation.geometry.y.values[0]
        lon = currLocation.geometry.x.values[0] + 360.
        # print(lat,lon)
        # print(means)
        # print(x)
        state_mean = means.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5),time=i['Year'] + '-' + i['Month'] + '-01')
        locate =  x.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5), time=datetime)

        # state_mean.t2m.plot()

        print(state_mean)

        # print(state_mean.t2m.to_numpy())
        # print(locate.t2m.to_numpy())


        anom = locate.sf.to_numpy() - state_mean.sf.to_numpy()

        if start:
            start = False
            anom_total = anom.flatten()
        else:
            anom_total = np.hstack((anom_total,anom.flatten()))
    state_sf_anoms.append(anom_total)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 256.5 256.8 257.0 257.2 ... 280.8 281.0 281.2
#   * latitude   (latitude) float32 48.5 48.25 48.0 47.75 ... 24.25 24.0 23.75
#     time       datetime64[ns] 2022-08-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 45.0 44.75 44.5 44.25 ... 20.75 20.5 20.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2023-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 227.8 228.0 228.2 228.5 ... 252.0 252.2 252.5
#   * latitude   (latitude) float32 50.5 50.25 50.0 49.75 ... 26.25 26.0 25.75
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 226.2 226.5 226.8 227.0 ... 250.5 250.8 251.0
#   * latitude   (latitude) float32 51.0 50.75 50.5 50.25 ... 26.75 26.5 26.25
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 226.2 226.5 226.8 227.0 ... 250.5 250.8 251.0
#   * latitude   (latitude) float32 51.0 50.75 50.5 50.25 ... 26.75 26.5 26.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 229.5 229.8 230.0 230.2 ... 253.8 254.0 254.2
#   * latitude   (latitude) float32 46.5 46.25 46.0 45.75 ... 22.25 22.0 21.75
#     time       datetime64[ns] 2023-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2022-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2022-10-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2023-05-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.2 266.5 266.8 267.0 ... 290.5 290.8 291.0
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.2 266.5 266.8 267.0 ... 290.5 290.8 291.0
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 265.2 265.5 265.8 266.0 ... 289.5 289.8 290.0
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.0 266.2 266.5 266.8 ... 290.2 290.5 290.8
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 265.2 265.5 265.8 266.0 ... 289.5 289.8 290.0
#   * latitude   (latitude) float32 42.0 41.75 41.5 41.25 ... 17.75 17.5 17.25
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.0 266.2 266.5 266.8 ... 290.2 290.5 290.8
#   * latitude   (latitude) float32 42.0 41.75 41.5 41.25 ... 17.75 17.5 17.25
#     time       datetime64[ns] 2023-05-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 253.5 253.8 254.0 254.2 ... 277.8 278.0 278.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 253.5 253.8 254.0 254.2 ... 277.8 278.0 278.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.2 258.5 258.8 259.0 ... 282.5 282.8 283.0
#   * latitude   (latitude) float32 52.5 52.25 52.0 51.75 ... 28.25 28.0 27.75
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.2 258.5 258.8 259.0 ... 282.5 282.8 283.0
#   * latitude   (latitude) float32 52.5 52.25 52.0 51.75 ... 28.25 28.0 27.75
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 261.5 261.8 262.0 262.2 ... 285.8 286.0 286.2
#   * latitude   (latitude) float32 52.75 52.5 52.25 52.0 ... 28.5 28.25 28.0
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 249.0 249.2 249.5 249.8 ... 273.2 273.5 273.8
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 262.5 262.8 263.0 263.2 ... 286.8 287.0 287.2
#   * latitude   (latitude) float32 50.0 49.75 49.5 49.25 ... 25.75 25.5 25.25
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 263.5 263.8 264.0 264.2 ... 287.8 288.0 288.2
#   * latitude   (latitude) float32 49.0 48.75 48.5 48.25 ... 24.75 24.5 24.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 43.25 43.0 42.75 42.5 ... 19.0 18.75 18.5
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 45.0 44.75 44.5 44.25 ... 20.75 20.5 20.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 43.25 43.0 42.75 42.5 ... 19.0 18.75 18.5
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-10-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
# ...
# Coordinates:
#   * longitude  (longitude) float32 269.2 269.5 269.8 270.0 ... 293.5 293.8 294.0
#   * latitude   (latitude) float32 49.5 49.25 49.0 48.75 ... 25.25 25.0 24.75
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 269.2 269.5 269.8 270.0 ... 293.5 293.8 294.0
#   * latitude   (latitude) float32 49.5 49.25 49.0 48.75 ... 25.25 25.0 24.75
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 269.2 269.5 269.8 270.0 ... 293.5 293.8 294.0
#   * latitude   (latitude) float32 49.5 49.25 49.0 48.75 ... 25.25 25.0 24.75
#     time       datetime64[ns] 2023-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-10-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2023-05-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.0 225.2 225.5 225.8 ... 249.2 249.5 249.8
#   * latitude   (latitude) float32 60.5 60.25 60.0 59.75 ... 36.25 36.0 35.75
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 59.75 59.5 59.25 59.0 ... 35.5 35.25 35.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.0 258.2 258.5 258.8 ... 282.2 282.5 282.8
#   * latitude   (latitude) float32 56.75 56.5 56.25 56.0 ... 32.5 32.25 32.0
#     time       datetime64[ns] 2022-08-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.0 258.2 258.5 258.8 ... 282.2 282.5 282.8
#   * latitude   (latitude) float32 56.75 56.5 56.25 56.0 ... 32.5 32.25 32.0
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 259.0 259.2 259.5 259.8 ... 283.2 283.5 283.8
#   * latitude   (latitude) float32 55.0 54.75 54.5 54.25 ... 30.75 30.5 30.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
for i in range(len(states)):
    plt.figure()
    plt.title(states[i] + ' Snowfall')
    plt.hist(state_sf_anoms[i], color='blue', edgecolor ='black', bins=60)
    plt.savefig('../visuals/sf_' + states[i] + '_hist.png')
# Out:
# /tmp/ipykernel_58441/2181263177.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
start = True
state_wind_anoms = []
for state in states:
    anom_total = []
    for i in state_dict[state]:
        means = xr.open_dataset('../../a/state_means/global_mean.nc')

        file_name = i['Month'] + '-' + i['Day'] + '-' + i['Year'] + '.nc'
        x = xr.open_dataset('../datafiles/' + file_name)
        currLocation = i['Location']
        datetime = i['Year'] + '-' + i['Month'] + '-' + i['Day'] + 'T12:00:00'

        # print(i['Year'] + '-' + i['Month'] + '-' + i['Day'])

        

        # print(state_mean.time)

        lat = currLocation.geometry.y.values[0]
        lon = currLocation.geometry.x.values[0] + 360.
        # print(lat,lon)
        # print(means)
        # print(x)
        state_mean = means.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5),time=i['Year'] + '-' + i['Month'] + '-01')
        locate =  x.sel(latitude=slice(lat+12.5,lat-12.5), longitude=slice(lon-12.5,lon+12.5), time=datetime)

        # state_mean.t2m.plot()

        print(state_mean)

        # print(state_mean.t2m.to_numpy())
        # print(locate.t2m.to_numpy())


        wind_mag = np.sqrt(np.square(locate.u10.to_numpy())+np.square(locate.v10.to_numpy()))
        wind_mean = np.sqrt(np.square(state_mean.u10.to_numpy())+np.square(state_mean.v10.to_numpy()))

        anom = wind_mag - wind_mean

        if start:
            start = False
            anom_total = anom.flatten()
        else:
            anom_total = np.hstack((anom_total,anom.flatten()))
    state_wind_anoms.append(anom_total)
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 260.8 261.0 261.2 261.5 ... 285.0 285.2 285.5
#   * latitude   (latitude) float32 45.75 45.5 45.25 45.0 ... 21.5 21.25 21.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 256.5 256.8 257.0 257.2 ... 280.8 281.0 281.2
#   * latitude   (latitude) float32 48.5 48.25 48.0 47.75 ... 24.25 24.0 23.75
#     time       datetime64[ns] 2022-08-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 45.0 44.75 44.5 44.25 ... 20.75 20.5 20.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2023-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.2 255.5 255.8 256.0 ... 279.5 279.8 280.0
#   * latitude   (latitude) float32 47.5 47.25 47.0 46.75 ... 23.25 23.0 22.75
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 227.8 228.0 228.2 228.5 ... 252.0 252.2 252.5
#   * latitude   (latitude) float32 50.5 50.25 50.0 49.75 ... 26.25 26.0 25.75
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 53.25 53.0 52.75 52.5 ... 29.0 28.75 28.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 226.2 226.5 226.8 227.0 ... 250.5 250.8 251.0
#   * latitude   (latitude) float32 51.0 50.75 50.5 50.25 ... 26.75 26.5 26.25
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 226.2 226.5 226.8 227.0 ... 250.5 250.8 251.0
#   * latitude   (latitude) float32 51.0 50.75 50.5 50.25 ... 26.75 26.5 26.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 229.5 229.8 230.0 230.2 ... 253.8 254.0 254.2
#   * latitude   (latitude) float32 46.5 46.25 46.0 45.75 ... 22.25 22.0 21.75
#     time       datetime64[ns] 2023-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2022-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2022-10-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 54.0 53.75 53.5 53.25 ... 29.75 29.5 29.25
#     time       datetime64[ns] 2023-05-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.2 266.5 266.8 267.0 ... 290.5 290.8 291.0
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.2 266.5 266.8 267.0 ... 290.5 290.8 291.0
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 265.2 265.5 265.8 266.0 ... 289.5 289.8 290.0
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.0 266.2 266.5 266.8 ... 290.2 290.5 290.8
#   * latitude   (latitude) float32 40.25 40.0 39.75 39.5 ... 16.0 15.75 15.5
#     time       datetime64[ns] 2022-09-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 265.2 265.5 265.8 266.0 ... 289.5 289.8 290.0
#   * latitude   (latitude) float32 42.0 41.75 41.5 41.25 ... 17.75 17.5 17.25
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.0 266.2 266.5 266.8 ... 290.2 290.5 290.8
#   * latitude   (latitude) float32 42.0 41.75 41.5 41.25 ... 17.75 17.5 17.25
#     time       datetime64[ns] 2023-05-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 264.5 264.8 265.0 265.2 ... 288.8 289.0 289.2
#   * latitude   (latitude) float32 44.75 44.5 44.25 44.0 ... 20.5 20.25 20.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 253.5 253.8 254.0 254.2 ... 277.8 278.0 278.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 253.5 253.8 254.0 254.2 ... 277.8 278.0 278.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.2 258.5 258.8 259.0 ... 282.5 282.8 283.0
#   * latitude   (latitude) float32 52.5 52.25 52.0 51.75 ... 28.25 28.0 27.75
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.2 258.5 258.8 259.0 ... 282.5 282.8 283.0
#   * latitude   (latitude) float32 52.5 52.25 52.0 51.75 ... 28.25 28.0 27.75
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 261.5 261.8 262.0 262.2 ... 285.8 286.0 286.2
#   * latitude   (latitude) float32 52.75 52.5 52.25 52.0 ... 28.5 28.25 28.0
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 249.0 249.2 249.5 249.8 ... 273.2 273.5 273.8
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 262.5 262.8 263.0 263.2 ... 286.8 287.0 287.2
#   * latitude   (latitude) float32 50.0 49.75 49.5 49.25 ... 25.75 25.5 25.25
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 263.5 263.8 264.0 264.2 ... 287.8 288.0 288.2
#   * latitude   (latitude) float32 49.0 48.75 48.5 48.25 ... 24.75 24.5 24.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 43.25 43.0 42.75 42.5 ... 19.0 18.75 18.5
#     time       datetime64[ns] 2022-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 45.0 44.75 44.5 44.25 ... 20.75 20.5 20.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 255.5 255.8 256.0 256.2 ... 279.8 280.0 280.2
#   * latitude   (latitude) float32 43.25 43.0 42.75 42.5 ... 19.0 18.75 18.5
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-10-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.5 275.8 276.0 276.2 ... 299.8 300.0 300.2
#   * latitude   (latitude) float32 54.75 54.5 54.25 54.0 ... 30.5 30.25 30.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
# ...
# Coordinates:
#   * longitude  (longitude) float32 269.2 269.5 269.8 270.0 ... 293.5 293.8 294.0
#   * latitude   (latitude) float32 49.5 49.25 49.0 48.75 ... 25.25 25.0 24.75
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 269.2 269.5 269.8 270.0 ... 293.5 293.8 294.0
#   * latitude   (latitude) float32 49.5 49.25 49.0 48.75 ... 25.25 25.0 24.75
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 269.2 269.5 269.8 270.0 ... 293.5 293.8 294.0
#   * latitude   (latitude) float32 49.5 49.25 49.0 48.75 ... 25.25 25.0 24.75
#     time       datetime64[ns] 2023-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-02-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-10-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2023-01-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 275.0 275.2 275.5 275.8 ... 299.2 299.5 299.8
#   * latitude   (latitude) float32 57.0 56.75 56.5 56.25 ... 32.75 32.5 32.25
#     time       datetime64[ns] 2023-05-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.0 225.2 225.5 225.8 ... 249.2 249.5 249.8
#   * latitude   (latitude) float32 60.5 60.25 60.0 59.75 ... 36.25 36.0 35.75
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 225.8 226.0 226.2 226.5 ... 250.0 250.2 250.5
#   * latitude   (latitude) float32 59.75 59.5 59.25 59.0 ... 35.5 35.25 35.0
#     time       datetime64[ns] 2022-12-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.0 258.2 258.5 258.8 ... 282.2 282.5 282.8
#   * latitude   (latitude) float32 56.75 56.5 56.25 56.0 ... 32.5 32.25 32.0
#     time       datetime64[ns] 2022-08-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 258.0 258.2 258.5 258.8 ... 282.2 282.5 282.8
#   * latitude   (latitude) float32 56.75 56.5 56.25 56.0 ... 32.5 32.25 32.0
#     time       datetime64[ns] 2022-11-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 259.0 259.2 259.5 259.8 ... 283.2 283.5 283.8
#   * latitude   (latitude) float32 55.0 54.75 54.5 54.25 ... 30.75 30.5 30.25
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2022-06-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-03-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...
# <xarray.Dataset>
# Dimensions:    (longitude: 100, latitude: 100)
# Coordinates:
#   * longitude  (longitude) float32 266.8 267.0 267.2 267.5 ... 291.0 291.2 291.5
#   * latitude   (latitude) float32 50.75 50.5 50.25 50.0 ... 26.5 26.25 26.0
#     time       datetime64[ns] 2023-04-01
# Data variables:
#     u10        (latitude, longitude) float32 ...
#     v10        (latitude, longitude) float32 ...
#     t2m        (latitude, longitude) float32 ...
#     i10fg      (latitude, longitude) float32 ...
#     msl        (latitude, longitude) float32 ...
#     sp         (latitude, longitude) float32 ...
#     tp         (latitude, longitude) float32 ...
#     sf         (latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-01 19:07:56 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
for i in range(len(states)):
    plt.figure()
    plt.title(states[i] + 'Wind')
    plt.hist(state_wind_anoms[i], color='blue', edgecolor ='black', bins=60)
    plt.savefig('../visuals/wind_' + states[i] + '_hist.png')
# Out:
# /tmp/ipykernel_58441/2472201551.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
